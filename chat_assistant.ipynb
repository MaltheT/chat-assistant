# %%
import pyaudio
import wave

# Set parameters for audio recording
FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 44100
CHUNK = 1024
RECORD_SECONDS = 5
WAVE_OUTPUT_FILENAME = "output.wav"

# Initialize audio object
audio = pyaudio.PyAudio()

# Open audio stream for recording
stream = audio.open(format=FORMAT, channels=CHANNELS,
                    rate=RATE, input=True,
                    frames_per_buffer=CHUNK)

# Record audio
frames = []
for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data)

# Close audio stream
stream.stop_stream()
stream.close()
audio.terminate()

# Save audio to file
wf = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
wf.setnchannels(CHANNELS)
wf.setsampwidth(audio.get_sample_size(FORMAT))
wf.setframerate(RATE)
wf.writeframes(b''.join(frames))
wf.close()

# %%
import whisper
model = whisper.load_model("base")

# %%
result = model.transcribe("output.wav")
result["text"]
# Out:
# ' What is 2 plus 1?'

# %%
import openai
import os
# from dotenv import load_dotenv

f = open(".env", "r")
key = f.readline()

# Set OpenAI API key
openai.api_key = key

# Define prompt and parameters
prompt = "Hello, how can I help you today?"
temperature = 0.7
max_tokens = 50

# Send request to OpenAI API
response = openai.Completion.create(
    engine="text-davinci-003",
    prompt=prompt,
    temperature=temperature,
    max_tokens=max_tokens,
)

# Print response from ChatGPT
print(response.choices[0].text.strip())
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipykernel_1169940/3292978036.py in <module>
#      16
#      17 # Send request to OpenAI API
# ---> 18 response = openai.Completion.create(
#      19     engine="text-davinci-003",
#      20     prompt=prompt,
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ~/anaconda3/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# ...

# %%
from resemble import Resemble
Resemble.api_key('8Jc6I6Qlg26a1b5YJvD4dQtt')
  
page = 1
page_size = 10
  
response = Resemble.v2.voices.all(page, page_size)
voices = response['items']
voice = voices[0]
# Out:
# {'uuid': '79eb7953',
#  'name': 'Whispering William',
#  'status': 'finished',
#  'created_at': '2022-01-19T23:45:16.888Z',
#  'updated_at': '2022-11-28T19:16:31.004Z'}

# %%
import pyttsx3

engine = pyttsx3.init()

# voices = engine.getProperty('voices')

for voice in voices:
	# to get the info. about various voices in our PC
	print("Voice:")
	print("ID: %s" %voice.id)
	print("Name: %s" %voice.name)
	print("Age: %s" %voice.age)
	print("Gender: %s" %voice.gender)
	print("Languages Known: %s" %voice.languages)


# Use female voice
engine.setProperty('voice', voice)


engine.say("hello")
engine.runAndWait()
# Out:
# Voice:
# ID: afrikaans
# Name: afrikaans
# Age: None
# Gender: male
# Languages Known: [b'\x05af']
# Voice:
# ID: aragonese
# Name: aragonese
# Age: None
# Gender: male
# Languages Known: [b'\x05an']
# Voice:
# ID: bulgarian
# Name: bulgarian
# Age: None
# Gender: None
# Languages Known: [b'\x05bg']
# Voice:
# ID: bengali
# Name: bengali
# Age: None
# Gender: male
# Languages Known: [b'\x05bn']
# Voice:
# ID: bosnian
# Name: bosnian
# Age: None
# Gender: male
# Languages Known: [b'\x05bs']
# Voice:
# ID: catalan
# Name: catalan
# Age: None
# Gender: male
# Languages Known: [b'\x05ca']
# Voice:
# ID: czech
# Name: czech
# Age: None
# Gender: male
# Languages Known: [b'\x05cs']
# Voice:
# ID: welsh
# Name: welsh
# Age: None
# Gender: male
# Languages Known: [b'\x05cy']
# Voice:
# ID: danish
# Name: danish
# Age: None
# Gender: male
# Languages Known: [b'\x05da']
# Voice:
# ID: german
# Name: german
# Age: None
# Gender: male
# Languages Known: [b'\x05de']
# Voice:
# ID: greek
# ...

# %%
from resemble import Resemble
Resemble.api_key('8Jc6I6Qlg26a1b5YJvD4dQtt')
  
name = 'My project'
description = 'My description'
is_public = False
is_archived = False
is_collaborative = False
  
response = Resemble.v2.projects.create(name, description, is_public, is_collaborative, is_archived)
project = response['item']
project
# Out:
# {'uuid': '9c2fc062',
#  'name': 'My project',
#  'description': 'My description',
#  'is_public': False,
#  'is_collaborative': False,
#  'is_archived': False,
#  'created_at': '2023-04-08T18:27:44.098Z',
#  'updated_at': '2023-04-08T18:27:44.098Z'}

# %%
clip = Resemble.v2.clips.create_sync('9c2fc062', '79eb7953', 'This is a test')
